# %%
from data_augmentation import DataEnhancer
from utils import load_data, get_labels
from PIL import Image

# %%
data = load_data('challenge_dataset/')

# %%
data_enhancer = DataEnhancer(data)

# %%
# try different params
data_enhancer.rand_rotate(max_abs_rot=40.)
# data_enhancer.sharpen(factor=1.1)
data_enhancer.contrast_raws(factor=1.4)
data_enhancer.crop(final_size=32)
# data_enhancer.clean_labels(dist_from_center_threshold=10.)
# data_enhancer.cluster_raws(n_colors=8)

# %%
labels = data_enhancer.labels()
for i, lab in enumerate(labels):
    if lab.max() != 1:
        print(i)

# %%
data_enhancer.save('augmented_data', index=2)
# Out:
# (108, 64, 32, 32)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(labels[51][29])

# %%
labs = get_labels(data)

# %%
for i in range(64):
    if labels[51][i].max() == 1:
        plt.imshow(labs[51][i+2])
        print(i+2)
        break
# Out:
# 29

# %%
lab_test= labs[51][29]

# %%
plt.imshow(lab_test)

# %%
lab_img = Image.fromarray(lab_test, mode='L')

# %%
plt.imshow(lab_img)

# %%
orig_size = 192
img_center = (orig_size // 2, orig_size // 2)
final_size = 32
x_left, x_right = img_center[0] - final_size // 2, img_center[0] + final_size // 2
y_top, y_bottom = img_center[1] - final_size // 2, img_center[1] + final_size // 2
lab_img = lab_img.crop(box=(x_left, y_top, x_right, y_bottom))
plt.imshow(lab_img)
